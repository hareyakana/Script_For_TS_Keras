# %%
import keras
from keras.models import Model, Sequential, load_model
from keras.layers import Input, Dense, Activation, Reshape, Conv1D , Conv2D, MaxPooling1D, MaxPooling2D, Dropout, Flatten, BatchNormalization, Embedding, LSTM

from keras.regularizers import l2
from keras.optimizers import SGD

model = Sequential()
model.add(Conv2D(8, kernel_size=1, activation="relu", input_shape=(64,64,1)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(16, 1, activation="relu"))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(32, 1, activation="relu"))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(256,activation="relu"))
model.add(Dropout(0.3))
model.add(Dense(128,activation="relu"))
model.add(Dropout(0.3))
model.add(Dense(64,activation="relu"))
model.add(Dropout(0.3))
model.add(Dense(32,activation="relu"))
model.add(Dropout(0.3))
model.add(Dense(6,activation="softmax"))
model.summary()

model2 = Sequential()
model2.add(Dense(10, activation="relu",input_shape=(10,)))
model2.add(Dense(10, activation="relu"))
model2.add(Dense(10, activation="relu"))
model2.summary()





model.compile(loss = 'binary_crossentropy', optimizer = "adam", metrics=['accuracy'])
# Out:
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 64, 64, 8)         16
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 8)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 16)        144
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 32)        544
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 32)          0
# ...

# %% [markdown]
# # Work plan
#
# Create 1 network that classify based on waveform, a secondary network that uses the output of 1st network plus some other parameters such as energy, time ratio, etc...
#
# train the 1st network first, then the 2nd network with the output of 1st network together with the remaining parameters.
#
#
# 3rd network using waveform 1d data ?
#
# 1st 2d of waveform
# 2nd paramters
# 3rd waveform itself without alteration

# %%
def waveform_classifier():
    model = Sequential()
    model.add(Reshape((64,64,1),input_shape=(64,64)))
    model.add(Conv2D(2, kernel_size=1))
    model.add(MaxPooling2D(pool_size=2))
    model.add(Activation("relu"))
    model.add(Conv2D(4, kernel_size=1,strides=2))
    model.add(MaxPooling2D(pool_size=2))
    model.add(Activation("relu"))
    model.add(Dropout(0.2))
    model.add(Flatten())
    model.add(Dense(256,activation="relu"))
    model.add(Dropout(0.3))
    model.add(Dense(128,activation="relu"))
    model.add(Dropout(0.3))
    model.add(Dense(64,activation="relu"))
    model.add(Dropout(0.3))
    model.add(Dense(32,activation="relu"))
    model.add(Dropout(0.3))
    model.add(Dense(6,activation="softmax"))
    model.summary()
    
    waveform = Input(shape=(64,64,1))
    label = model(waveform)
    
    return Model(waveform,label)

def support_classifier():
    model = Sequential()
    model.add(Dense(30, activation="relu",input_shape=(10,)))
    model.add(Dense(20, activation="relu"))
    model.add(Dense(10, activation="relu"))
    model.add(Dense(6, activation="relu"))
    model.summary()
    
    parameters = Input(shape=(10,))
    label = model(parameters)
    return Model(parameters,label)

def waveform_1d_classifier():
    model = Sequential()
    model.add(Reshape((4096,1),input_shape=(4096,)))
    model.add(Conv1D(16, kernel_size=2, strides=4))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Activation("relu"))
    model.add(Conv1D(32, kernel_size=2, strides=4))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Activation("relu"))
    model.add(Conv1D(64, kernel_size=2, strides=4))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Activation("relu"))
    model.add(Flatten())
    model.add(Dense(64))
    model.add(Activation("relu"))
    model.add(Dense(32, activation="relu"))
    model.add(Dense(6, activation="relu"))
    model.summary()
    
    waveform = Input(shape=(4096,1))
    label = model(waveform)
    
    return Model(waveform,label)

# %%
waveform = waveform_classifier()
waveform_1d = waveform_1d_classifier()
parameters = support_classifier()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# reshape_3 (Reshape)          (None, 64, 64, 1)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 64, 64, 2)         4
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 32, 32, 2)         0
# _________________________________________________________________
# activation_7 (Activation)    (None, 32, 32, 2)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 4)         12
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 8, 8, 4)           0
# _________________________________________________________________
# activation_8 (Activation)    (None, 8, 8, 4)           0
# ...
